# %% [markdown]
# 1)
# c.51000

# %% [markdown]
# 2)
# d.40

# %% [markdown]
# 3)
# b.720

# %% [markdown]
# 4)
# c.60 km/h

# %% [markdown]
# 5)
# b.10

# %% [markdown]
# 6)
# c.140

# %% [markdown]
# 7)
# c.42

# %% [markdown]
# 8)
# d.cylinder

# %% [markdown]
# 9)
# c.u

# %% [markdown]
# 10)
# c.jhon

# %% [markdown]
# 11)
# d.sunday

# %% [markdown]
# 12)
# d.may

# %% [markdown]
# 13)
# c.270

# %% [markdown]
# 14)
# c.162

# %% [markdown]
# 15)
# c.april

# %% [markdown]
# 16)
# a.1/2

# %% [markdown]
# 17)
# b.72,75,80

# %% [markdown]
# 18)
# d.40

# %% [markdown]
# 19)
# b.18

# %% [markdown]
# 20)
# b.40%

# %% [markdown]
# 21)
# b.[4,6,8,10]

# %% [markdown]
# 22)
# a.analytics

# %% [markdown]
# 23)
# c.20

# %% [markdown]
# 24)
# a. 30
# [10,20,40]

# %% [markdown]
# 25)
# c.1,3,5

# %% [markdown]
# section-b logical & conceptual
